# %%
import pandas as pd

# Giải thích: 
# Bước 1: '../' -> Lùi ra khỏi thư mục 'scripts' để đứng ở thư mục gốc (Credit_Risk_Analysis)
# Bước 2: 'data/raw/loan.csv' -> Từ thư mục gốc, đi thẳng vào tìm file
file_path = '../data/raw/loan.csv'

print("Đang đọc file...")
df_snapshot = pd.read_csv(file_path, nrows=1000, low_memory=False)

print("Đọc file thành công! Số dòng và cột hiện tại là:", df_snapshot.shape)
# Out:
# Đang đọc file...
# Đọc file thành công! Số dòng và cột hiện tại là: (1000, 145)
