# %%
import pandas as pd

file_path = '../data/raw/loan.csv'
df = pd.read_csv(file_path)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_19708\1230900562.py:4: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (2260668, 145)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Columns: 145 entries, id to settlement_term
# dtypes: float64(105), int64(4), object(36)
# memory usage: 2.4+ GB

# %%
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 145 entries, id to settlement_term
# dtypes: float64(65), int64(55), object(25)
# memory usage: 1.1+ MB
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0   1000.000000   1000.000000      1000.000000
# mean   NaN        NaN  15657.750000  15657.750000     15656.375000
# std    NaN        NaN  10276.000797  10276.000797     10277.302622
# min    NaN        NaN   1000.000000   1000.000000       975.000000
# 25%    NaN        NaN   7500.000000   7500.000000      7500.000000
# 50%    NaN        NaN  13000.000000  13000.000000     13000.000000
# 75%    NaN        NaN  22000.000000  22000.000000     22000.000000
# max    NaN        NaN  40000.000000  40000.000000     40000.000000
#
#           int_rate  installment    annual_inc  url  desc  ...  \
# count  1000.000000  1000.000000  1.000000e+03  0.0   0.0  ...
# mean     13.050820   454.249320  8.492460e+04  NaN   NaN  ...
# std       4.913656   287.383903  6.686111e+04  NaN   NaN  ...
# min       6.460000    30.640000  0.000000e+00  NaN   NaN  ...
# 25%       8.810000   235.800000  5.000000e+04  NaN   NaN  ...
# 50%      11.800000   377.090000  7.000000e+04  NaN   NaN  ...
# 75%      16.140000   621.277500  1.000000e+05  NaN   NaN  ...
# max      30.750000  1379.960000  1.120000e+06  NaN   NaN  ...
#
#        hardship_loan_status  orig_projected_additional_accrued_interest  \
# count                   0.0                                         0.0
# mean                    NaN                                         NaN
# std                     NaN                                         NaN
# min                     NaN                                         NaN
# 25%                     NaN                                         NaN
# 50%                     NaN                                         NaN
# 75%                     NaN                                         NaN
# max                     NaN                                         NaN
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                             0.0                           0.0
# mean                              NaN                           NaN
# std                               NaN                           NaN
# min                               NaN                           NaN
# 25%                               NaN                           NaN
# 50%                               NaN                           NaN
# 75%                               NaN                           NaN
# max                               NaN                           NaN
#
#        debt_settlement_flag_date  settlement_status  settlement_date  \
# count                        0.0                0.0              0.0
# mean                         NaN                NaN              NaN
# std                          NaN                NaN              NaN
# min                          NaN                NaN              NaN
# 25%                          NaN                NaN              NaN
# 50%                          NaN                NaN              NaN
# 75%                          NaN                NaN              NaN
# max                          NaN                NaN              NaN
#
#        settlement_amount  settlement_percentage  settlement_term
# count                0.0                    0.0              0.0
# mean                 NaN                    NaN              NaN
# std                  NaN                    NaN              NaN
# min                  NaN                    NaN              NaN
# 25%                  NaN                    NaN              NaN
# 50%                  NaN                    NaN              NaN
# 75%                  NaN                    NaN              NaN
# max                  NaN                    NaN              NaN
#
# [8 rows x 120 columns]

# %%
columns_to_keep = [
    'loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
    'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
    'issue_d', 'loan_status', 'purpose', 'dti', 'delinq_2yrs',
    'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc'
]
df = df[columns_to_keep]

valid_statuses = ['Fully Paid', 'Charged Off', 'Default']
df = df[df['loan_status'].isin(valid_statuses)]

df = df.sample(n=50000, random_state=42)

output_path = '../data/processed/Lending_Club_Sampled_50k.csv'

# %%
df.to_csv(output_path, index=False)

# %%
df.shape
# Out:
# (50000, 21)
